# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#     pip install --upgrade pandas

# %%
data = pd.read_csv('../002_datos/esolmet.csv',index_col=0,parse_dates=True,
                  skiprows=[0,1,3,4])
data
# Out:
#                      Directa  Global  Difusa     UV  Temperatura  Humedad  \
# Fecha
# 2019-05-03 00:00:00    0.000   0.000     0.0  0.186        23.02    47.67
# 2019-05-03 00:10:00    0.000   0.000     0.0  0.183        22.95    48.15
# 2019-05-03 00:20:00    0.000   0.000     0.0  0.184        23.01    47.78
# 2019-05-03 00:30:00    0.000   0.000     0.0  0.183        22.83    47.67
# 2019-05-03 00:40:00    0.000   0.000     0.0  0.185        22.69    48.32
# ...                      ...     ...     ...    ...          ...      ...
# 2019-06-24 23:20:00    0.132   0.000     0.0  0.000        23.52    76.54
# 2019-06-24 23:30:00    0.150   0.000     0.0  0.000        23.54    77.08
# 2019-06-24 23:40:00    0.112   0.000     0.0  0.000        23.39    79.91
# 2019-06-24 23:50:00    0.155   0.000     0.0  0.000        23.16    80.50
# 2019-06-25 00:00:00    0.012   0.184     0.0  0.000        22.48    84.40
#
#                      Viento Vel.  Presiòn Bar.
# Fecha
# ...

# %%
data.plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Fecha'>, <AxesSubplot:xlabel='Fecha'>,
#        <AxesSubplot:xlabel='Fecha'>, <AxesSubplot:xlabel='Fecha'>,
#        <AxesSubplot:xlabel='Fecha'>, <AxesSubplot:xlabel='Fecha'>,
#        <AxesSubplot:xlabel='Fecha'>, <AxesSubplot:xlabel='Fecha'>],
#       dtype=object)
